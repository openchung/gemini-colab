# %% [markdown]
# # Google Gen AI SDK
#
# google-genai 是用於與 Google 的 Generative AI API 互動的初始 Python 用戶端程式庫。
#
# Google Gen AI Python SDK 為開發人員提供了一個接口，可以將 Google 的生成模型整合到他們的 Python 應用程式中。它支援Gemini 開發者 API和Vertex AI API。

# %% [markdown]
# ## I. Installation
#
# 透過 pip 安裝 python package

# %%
# !pip install -q google-genai

# %% [markdown]
# ## II. Import and create a client

# %% [markdown]
# ### Method 1: 非變數的使用方法

# %%
from google import genai
from google.genai import types

gemini_env_bool = "False" #@param ["True", "False"]
gemini_type = 'google-ai-studio' #@param ["google-ai-studio", "google-vertex-ai"]

# google-ai-studio
vertex_ai_project = 'your-project-id' #@param {type:"string"}
vertex_ai_location = 'us-central1' #@param {type:"string"}

# %%
# Only run this block for Gemini Developer API
from google.colab import userdata

if gemini_env_bool == "False" and gemini_type == "google-ai-studio":
    client = genai.Client(api_key=userdata.get('GOOGLE_API_KEY'))

# %%
# Only run this block for Vertex AI API
if gemini_env_bool == "False" and gemini_type == "google-vertex-ai":
    client = genai.Client(
        vertexai=True, project='your-project-id', location='us-central1'
    )

# %% [markdown]
# ### Method 2: 環境變數的使用方法
#
# 如果你在環境變數設定以下變數：
# ```
# # google-ai-studio
# !export GOOGLE_API_KEY='your-api-key'
#
# # google-vertex-ai
# !export GOOGLE_GENAI_USE_VERTEXAI=true
# !export GOOGLE_CLOUD_PROJECT='your-project-id'
# !export GOOGLE_CLOUD_LOCATION='us-central1'
# ```
# 那你就可以直接使用以下程式碼設定 client：

# %%
if gemini_env_bool == "True":
    client = genai.Client()

# %% [markdown]
# ## III. API 測試

# %%
response = client.models.generate_content(
    model='gemini-2.0-flash-001', contents='請問為何天空是藍色的？'
)
print(response.text)
# Out:
# 天空呈現藍色的主要原因是**瑞利散射 (Rayleigh scattering)**。
#
# 以下是更詳細的解釋：
#
# * **陽光是由不同顏色的光組成的：** 我們看到的白色的陽光，其實是由紅、橙、黃、綠、藍、靛、紫等不同顏色的光組成的。
# * **光線與空氣分子碰撞：** 當太陽光進入地球大氣層時，會與空氣中的微小分子（主要是氮氣和氧氣）碰撞。
# * **瑞利散射效應：** 這種碰撞會使光線向四面八方散射。  瑞利散射的散射強度與光波長的四次方成反比。  這意味著波長較短的光（例如藍光和紫光）比波長較長的光（例如紅光）更容易被散射。
# * **藍光被大量散射：** 因此，藍光和紫光在大氣層中被大量散射。
# * **我們看到藍色的天空：** 由於藍光比紫光散射得更多，而且我們的眼睛對藍光比紫光更敏感，所以我們看到的天空主要是藍色的。
#
# **其他需要考慮的因素：**
#
# * **太陽在不同位置：**  當太陽接近地平線（日出和日落）時，陽光需要穿過更厚的大氣層。  這使得藍光在到達我們眼睛之前被散射得更多，而紅光和橙光則能夠穿透，因此我們看到日出和日落時天空呈現紅色或橙色。
# * **大氣中的其他粒子：** 空氣中的其他粒子，例如水蒸氣和灰塵，也會影響光的散射，但瑞利散射仍然是主要原因。
#
# **簡而言之：** 因為藍光比其他顏色的光更容易被大氣層中的分子散射，所以我們看到的天空是藍色的。

# %% [markdown]
# ## IV. 上傳檔案後使用 API
#
# 你可以透過 API 上傳檔案，並且對檔案進行 AI 的問答。

# %%
# !wget -q https://storage.googleapis.com/generativeai-downloads/data/a11.txt

# %%
file = client.files.upload(file='a11.txt')
response = client.models.generate_content(
    model='gemini-2.0-flash-001',
    contents=['你可以使用繁體中文幫我統整此內容嗎？', file]
)
print(response.text)
# Out:
# 好的，這是將您提供的內容整理成繁體中文的版本：
#
# **阿波羅11號任務空對地語音記錄 (GOSS NET 1)**
#
# **簡介**
#
# 這份文件是阿波羅11號任務中，技術性的空對地語音傳輸記錄 (GOSS NET 1)。
#
# 以下列出文本中出現的通訊人員及其代號：
#
# *   **太空船:**
#     *   CDR：指揮官（Commander） - 尼爾·A·阿姆斯壯（Neil A. Armstrong）
#     *   CMP：指令艙駕駛員（Command Module Pilot） - 麥可·科林斯（Michael Collins）
#     *   LMP：登月艙駕駛員（Lunar Module Pilot） - 小艾德溫·E·艾德林（Edwin E. Aldrin, Jr.）
#     *   SC：無法辨識的組員
#     *   MS：多重（同時）發言者
#     *   LCC：發射控制中心（Launch Control Center）
# *   **任務控制中心:**
#     *   CC：太空艙通訊員（Capsule Communicator，CAP COMM）
#     *   F：飛行指揮官（Flight Director）
# *   **遠端站點:**
#     *   CT：通訊技術員（Communication Technician，COMM TECH）
# *   **搜救部隊:**
#     *   HORNET：黃蜂號航空母艦（USS Hornet）
#     *   R：搜救直升機（Recovery Helicopter）
#     *   AB：航空指揮官（Air Boss）
#
# 一系列的三個點（...）表示由於語音不清，無法謄錄的通訊部分。一個破折號（-）表示說話者的暫停或自我打斷，然後完成想法。兩個破折號（--）表示被另一位說話者打斷，或錄音突然終止的位置。
#
# **阿波羅11號空對地語音記錄**
#
# （GOSS NET 1）磁帶 1/1 第 1 頁
#
# MILA（REV 1）
#
# 00 00 00 04 CDR
# 收到。時鐘。
#
# 00 00 00 13 CDR
# 收到。我們有一個滾轉程序。
#
# 00 00 00 15 CMP
# 收到。滾轉。
#
# 00 00 00 34 CDR
# 滾轉完成，俯仰已編程。
#
# 00 00 00 44 CDR
# 一布拉沃。
#
# 00 00 01 02 CC
# 阿波羅11號，休士頓。你在一分鐘時狀態良好。
#
# 00 00 01 06 CDR
# 收到。
#
# 00 00 01 54 CC
# 準備模式一查理。
#
# 00 00 01 57 CC
# 標記。
#
# 00 00 01 58 CC
# 模式一查理。
#
# 00 00 01 59 CDR
# 一查理。
#
# 00 00 02 03 CC
# 阿波羅11號，這裡是休士頓。你已批准分級。
#
# 00 00 02 17 CDR
# 內側關閉。
#
# 00 00 02 19 CC
# 我們確認內側關閉。
#
# 00 00 02 44 CDR
# 分級。
#
# 00 00 02 46 CDR
# 點火。
#
# 00 00 02 55 CC
# 11號，休士頓。推力狀態良好，所有引擎。你看起來很棒。
#
# 00 00 02 59 CDR
# 收到。你聽起來很清楚，休士頓。
#
# 00 00 03 13 CDR
# 我們有護罩分離。
#
# 00 00 03 15 CC
# 收到。我們確認。護罩分離。
#
# 00 00 03 17 CDR
# 塔架已脫離。
#
# 00 00 03 19 CC
# 收到。塔架。
#
# 00 00 03 28 CDR
# 休士頓，請注意，今天的視野良好。
#
# 00 00 03 32 CC
# 這裡是休士頓。收到。結束。
#
# （GOSS NET 1）磁帶 1/2 第 2 頁
#
# 00 00 03 36 CDR
# 是的。他們終於給了我一個可以往外看的窗戶。
#
# 00 00 03 44 CC
# 11號，休士頓。你的導航已經收斂；你看起來很棒。
#
# 00 00 03 52 CDR
# 收到。
#
# 00 00 04 01 CC
# 11號，休士頓。你在 4 分鐘時狀態良好。
#
# 00 00 04 04 CDR
# 收到。
#
# 00 00 05 03 CC
# 11號，休士頓。你在 5 分鐘時狀態良好。
#
# 00 00 05 06 CDR
# 收到。它會 - 阿波羅 11 號。啟動。
#
# 00 00 05 21 CC
# 準備 S-IVB 到 COI 的能力。
#
# 00 00 05 25 CDR
# 好的。
#
# 00 00 05 27 CC
# 標記。
#
# 00 00 05 28 CC
# S-IVB 到 COI 的能力。
#
# 00 00 05 30 CDR
# 收到。
#
# 00 00 05 35 CDR
# 你聽起來真清楚，布魯斯。聽起來像你坐在客廳裡。
#
# 00 00 05 39 CC
# 哦，謝謝你。你們也都傳送得非常棒。
#
# 00 00 06 00 CDR
# 我們正在進行 6 分鐘。啟動萬向節電機。
#
# 00 00 06 03 CC
# 收到，11號。你在 6 分鐘時從地面狀態良好。
#
# 00 00 06 20 CC
# 阿波羅11號，這裡是休士頓。水平感應臂在 8 分鐘加 17 秒；外側關閉在 9 分鐘加 11 秒。
#
# 00 00 07 01 CDR
# 阿波羅11號在 7 分鐘時狀態良好。
#
# 00 00 07 04 CC
# 11號，這裡是休士頓。收到。你在 7 分鐘時從地面狀態良好。水平感應臂在 8 分鐘加 17 秒；外側關閉在 9 分鐘加 11 秒。
#
# 00 00 07 09 CDR
# 收到。
#
# 00 00 07 42 CDR
# 內側關閉。
#
# 00 00 07 45 CC
# 收到。我們已確認。
#
# 00 O0 08 19 CC
# 阿波羅11號，休士頓。你在 8 分鐘時狀態良好。
#
# （GOSS NET 1）磁帶 1/3 第 3 頁
#
# 00 00 08 22 CDR
# AGS 剛剛發生混合比率轉變。
#
# 00 00 08 24 CC
# 收到。我們也偵測到 PU 的轉變。
#
# 00 00 08 34 CDR
# 嗯，今天天氣看來不錯。只有這些下游的雷雨。
#
# 大巴哈馬群島（REV 1）
#
# 00 00 08 52 CC
# 11號，這裡是休士頓。你已批准分級。結束。
#
# 00 00 08 56 CDR
# 了解，批准分級。還有 - -
#
# 00 00 08 57 CC
# 準備模式 IV 能力。
#
# 00 00 08 59 CDR
# 好的。模式 IV。
#
# 00 00 09 00 CC
# 標記。
#
# 00 00 09 01 CC
# 模式 IV 能力。
#
# 00 00 09 15 CDR
# 分級 -
#
# 00 00 09 16 CDR
# - 還有點火。
#
# 00 00 09 19 CC
# 點火確認；推力狀態良好，11 號。
#
# 00 00 10 01 CC
# 阿波羅11號，這裡是休士頓。在 10 分鐘時，你狀態良好。
#
# 00 00 10 06 CDR
# 收到。11號狀態良好。
#
# 00 00 10 24 CC
# 阿波羅11號，這裡是休士頓。預測關閉時間為 11 分鐘加 42 秒。結束。
#
# 00 00 10 29 CDR
# 11 42。收到。
#
# 00 00 11 03 CC
# 阿波羅11號，這裡是休士頓。你在 11 分鐘時狀態良好。
#
# 00 00 11 08 CDR
# 很好。
#
# 00 00 11 42 CDR
# 關閉。
#
# 00 00 11 45 CMP
# SECO。我們顯示 101.4 乘 103.6。
#
# 00 00 11 51 CC
# 收到。關閉。我們複製 101.4 乘 103.6。
#
# 00 00 12 06 CC
# 阿波羅11號，這裡是休士頓。你已確認狀態良好，可以進入軌道。
#
# （GOSS NET 1）磁帶 1/4 第 4 頁
#
# 00 00 12 12 CDR
# 收到。
#
# 00 00 12 24 CC
# 阿波羅11號，這裡是休士頓。助推器安全。
#
# 00 00 12 29 CDR
# 收到。
#
# 先鋒（REV 1）
#
# 00 00 13 27 CC
# 阿波羅11號，這裡是休士頓。助推器已經配置為軌道滑行。兩個太空船看起來狀態都很好。結束。
#
# 00 00 13 35 CDR
# 收到。
#
# 00 00 14 33 CC
# 阿波羅11號，這裡是休士頓。先鋒 LOS 在 15 35；AOS 加那利群島在 16 30。結束。
#
# 00 00 14 43 CDR
# 好的。謝謝你。
#
# 加那利（REV 1）
#
# 00 00 17 38 CT ... 休士頓 COMM TECH。加那利 COMM TECH。
#
# 00 00 18 18 CC
# 阿波羅11號，這裡是透過加那利群島的休士頓。結束。
#
# 00 00 18 23 CDR
# 收到。讀你大聲且清楚。我們的進入清單已完成，我們沒有發現任何異常。
#
# 00 00 18 30 CC
# 收到。如果你準備好複製，我想在這個時候傳送你的 Delta 方位角修正。結束。
#
# 00 00 18 36 CDR
# 稍等。
#
# 00 00 18 40 CDR
# 收到。請繼續。準備複製。
#
# 00 00 18 42 CC
# 好的。Delta 方位角修正為正 0.22，也就是正 0.22，我們建議進行 P52 對齊。結束。
#
# 00 00 18 54 CDR
# 好的。我們將繼續進行 P52，並偵測到正 0.22 的角度。
#
# 00 00 19 O1 CC
# 收到。你在加那利群島的 LOS 時間是 23 37。結束。
#
# 00 00 19 09 CDR
# 23 37。
#
# （GOSS NET 1）磁帶 1/5 第 5 頁
#
# 00 00 19 11 CC
# 休士頓。收到。結束。
#
# 00 00 22 41 CC
# 阿波羅11號，這裡是休士頓。距離 LOS 加那利群島還有一分鐘；A0S 在塔那那利佛 37 04，以 VHF Simplex Alfa 傳送。結束。
#
# 00 00 23 08 CC
# 阿波羅11號，這裡是休士頓。即將到達 LOS 加那利群島；AOS 塔那那利佛在 37 04，Simplex Alfa。休士頓。結束。
#
# 00 00 23 23 CDR
# 阿波羅。收到。
#
# 塔那那利佛（REV 1）
#
# 00 00 38 37 CC
# 阿波羅11號，這裡是透過塔那那利佛的休士頓。結束。
#
# 00 00 38 50 CC
# 阿波羅11號，阿波羅11號，這裡是透過塔那那利佛的休士頓。結束。
#
# 00 00 39 04 CDR
# 休士頓，阿波羅11號。我在 VHF A Simplex 上讀到你。你讀到我嗎？結束。
#
# 00 00 39 10 CC
# 收到，11 號。這裡是休士頓。我們讀到你大聲且相當清楚。供你參考，加那利雷達顯示你位於 103.0 乘 103.0 的軌道上。結束。
#
# 00 00 39 25 CDR
# 太棒了。
#
# 00 00 39 27 CC
# 收到。我們同意。
#
# 00 00 39 31 CDR
# ... 我們剛進入這裡的終端區。
#
# 00 00 41 44 CC
# 阿波羅11號，這裡是休士頓。距離 LOS 塔那那利佛還有一分鐘；AOS 卡納封在 52 15。結束。
#
# 00 00 41 54 CDR
# 孤軍奮戰。收到。
#
# 00 00 43 13 CT TAN LOS。
#
# 卡納封（REV 1）
#
# 00 00 53 03 CC
# 阿波羅11號，這裡是透過卡納封的休士頓。無線電檢查。結束。
#
# 00 00 53 08 LMP
# 休士頓，阿波羅11號。大聲且清楚。結束。
#
# （GOSS NET 1）磁帶 1/6 第 6 頁
#
# 00 00 53 11 CC
# 收到，11 號。我們讀到你也是一樣。助推器和太空船對我們來說看起來都很好。結束。
#
# 00 00 53 26 LMP
# 休士頓，阿波羅11號。你想要複製對齊結果嗎？
#
# 00 00 53 31 CC
# 這是肯定的。
#
# 00 00 53 35 LMP
# 好的。名詞 71：我們使用 30 和 37，四個球 1；名詞 93：正 00016，正 00033，正 00152；GET 00 48 15；檢查星 34。結束。
#
# 00 00 54 02 CC
# 收到。再說一次檢查星。
#
# 00 00 54 06 LMP
# 檢查星 34。
#
# 00 00 54 09 CC
# 收到。我們複製。而且角度看起來不錯。
#
# 00 00 54 13 CMP
# 並告訴海角的葛倫·帕克，他走運了。
#
# 00 00 54 17 CC
# 了解。告訴葛倫·帕克他走運了。
#
# 00 00 54 22 CMP
# 是的。他走運了。他不欠我一杯咖啡。
#
# 00 00 54 26 CC
# 這裡是休士頓。收到。我們會轉達。
#
# 00 00 57 27 CC
# 阿波羅11號，這裡是休士頓。距離 LOS 卡納封還有一分鐘；AOS 在蜂蜜吸盤 59 33。結束。
#
# 00 00 57 37 CDR
# 阿波羅11號。收到。
#
# 00 00 57 40 CC
# 收到。我們要求你調高蜂蜜吸盤傳輸的 S 波段音量。
#
# 蜂蜜吸盤（REV 1）
#
# 00 01 02 48 CC
# 阿波羅11號，阿波羅11號，這裡是 S 波段的休士頓。無線電檢查。結束。
#
# 00 01 02 55 CDR
# 收到，休士頓。阿波羅11號讀到你大聲且清楚。
#
# 00 01 02 58 CC
# 這裡是休士頓。收到。讀到你也是一樣。結束。
#
# 00 01 04 24 CC
# 阿波羅11號，這裡是休士頓。距離蜂蜜吸盤的 LOS 還有 1 分鐘多一點。你將在 Goldstone 的 1 29 02 獲得 AOS；LOS 在 Goldstone 的 1 33 55。結束。
#
# （GOSS NET 1）磁帶 1/7 第 7 頁
#
# 00 01 04 47 CMP
# 收到，布魯斯。謝謝你。我們預期有電視。我們已經把它全部連接起來。我們還沒有打開它。我們現在準備這樣做。GUAYMAS（REV 1）
#
# 00 01 29 09 CC
# 阿波羅11號，這裡是透過瓜伊馬斯的休士頓。結束。
#
# 00 01 29 14 CDR
# 收到，休士頓。讀你大聲且清楚。
#
# 00 01 29 17 CC
# 收到。讀到你也是一樣。即將到達 AOS Goldstone。
#
# 00 01 29 20 CDR
# 收到。
#
# 磁帶結束
#
# （GOSS NET 1）磁帶 1/8 第 8 頁
#
# 注意
#
# 在 TLI 之後，Goldstone (GDS)、馬德里 (MAD) 和蜂蜜吸盤 (HSK) 之間持續獲取訊號。
#
# 阿波羅11號空對地語音記錄
#
# （GOSS NET 1）磁帶 2/1 第 9 頁
#
# 瓜伊馬斯（REV 1）
#
# 00 01 29 27 LMP
# Cecil B. deAldrin 正在等待指示。
#
# 00 01 29 32 CC
# 休士頓。收到。
#
# 00 01 31 15 CC
# 阿波羅11號，這裡是休士頓。我們尚未收到你的 FM 下行鏈路。我們正在等待。
#
# 00 01 31 56 CC
# 阿波羅11號，這裡是休士頓。我們現在收到你的 FM 下行鏈路。我們正在等待訊號上的電視調變。
#
# 00 01 32 23 CC
# 阿波羅11號，阿波羅11號，這裡是休士頓。無線電檢查。結束。
#
# Goldstone（REV 1）
#
# 00 01 32 27 CDR
# 收到。大聲且清楚。我們認為我們正在向你傳輸。
#
# 00 01 32 31 CC
# 好的。我們尚未收到它，11 號，儘管我們已確認你的 FM 下行鏈路載波存在。
#
# 00 01 32 39 CDR
# 你想要我們確認哪些開關？
#
# 00 01 32 42 CC
# 稍等。
#
# 德克薩斯（REV 1）
#
# 00 01 33 11 CC
# 阿波羅11號，這裡是休士頓。你剛剛位於 Goldstone 覆蓋範圍的邊緣。我們剛剛在 Goldstone 失去了 LOS，我們想要繼續前進，並盡快向你讀出 PAD 訊息。
#
# 00 01 33 26 CDR
# 收到。我們準備複製。
#
# 00 01 34 33 CC
# 阿波羅11號，這裡是休士頓。我準備好你的 TLI 加 90 分鐘的中止 PAD。
#
# 00 01 34 55 CC
# 阿波羅11號，這裡是休士頓。我準備好你的 TLI 加 90 分鐘的中止 PAD。
#
# （GOSS NET 1）磁帶 2/2 第 10 頁
#
# 00 01 35 00 CDR
# 收到。阿波羅11號準備複製 TLI 加 90。
#
# 00 01 35 03 CMP
# 開始。
#
# 00 01 35 05 CC
# 收到。TLI 加 90，SPS G&N：63481，減 153，加 132；GETI 004 10 25 38；名詞 81，減 04761，加 00001，加 53361；滾轉 180 193 000；HA 為 NA；加 00203 53573 633 53349，六分儀星 33 1578 122。瞄準線星不可用。緯度減 0252，減 02580 11887 34345 016 03 50。GDC 對齊織女星和天津四。滾轉 071 291 341。無耗盡，已脫離。我有你的 P37，適用於 TLI 加 5 小時。結束。
#
# 00 01 37 08 CMP
# 請繼續，TLI 加 5。
#
# 00 01 37 11 CC
# 收到。P37 格式，TLI 加 5：00744 6485，減 165，02506。回讀。結束。
#
# 00 01 37 31 CMP
# 收到。TLI 加 90，SPS G&N：63481，減 153，加 132，004 l0 25 38，減 04761，加 00001，加 53361，180 193 000，不適用，加 00203 53573 633 53349，33 1578 122，不可用，減 0252，減 02580 11887 34345 016 03 50。織女星和天津四，071 291 341。無耗盡，已脫離。P37，TLI 加 5：00744 6485，減 165 02506。結束。
#
# 00 01 39 04 CC
# 阿波羅11號，這裡是休士頓。回讀正確。供你參考，Goldstone 報告收到大約 1 分鐘的 FM 下行鏈路載波。我們正準備要求你確認 S 波段 AUX 開關，S 波段 AUX 磁帶開關至 OFF，以及 S 波段 AUX 電視開關至 TV。結束。
#
# 00 01 39 29 CDR
# 我確認這就是我們所處的配置。
#
# 00 01 39 33 CC
# 收到。讓我們在這裡做一些更多的偵查工作，我們看看是否能找到一些東西。
#
# 00 01 39 38 CDR
# 好的。
#
# 00 01 39 54 CDR
# 休士頓，阿波羅11號準備好繼續 - 延伸對接探針，並準備好在您準備好監視時進行 RCS 熱火。結束。
#
# 00 01 40 06 CC
# 收到。現在繼續進行探針。
#
# （GOSS NET 1）磁帶 2/3 第 11 頁
#
# 00 01 40 13 CDR
# 收到。
#
# 00 01 41 33 CDR
# 好的。當你準備好時，我們準備好進行熱火檢查。
#
# 00 01 41 39 CC
# 收到。我們準備好 11 號。請繼續。
#
# 00 01 41 48 CDR
# 收到。這是俯仰。
#
# 00 01 42 13 CC
# 阿波羅11號，這裡是休士頓。我們看到了俯仰熱火，看起來不錯。
#
# 00 01 42 18 CDR
# 收到。請注意，我們無法聽到它們。
#
# 00 01 42 22 CC
# 收到。我們複製。
#
# 00 01 42 24 CDR
# 你看到了所有三個軸的發射嗎？
#
# 00 01 42 31 CC
# 我們看到了俯仰和偏航；我們迄今尚未看到滾轉。
#
# 00 01 42 36 CDR
# 好的。我將放入更多滾轉。
#
# 00 01 42 42 CC
# 好的。我們得到了滾轉脈衝，你在這裡看起來不錯。
#
# 00 01 42 48 CDR
# 收到。休士頓，阿波羅11號。我們正在等待批准啟動序列邏輯。
#
# 00 01 43 03 CC
# 阿波羅11號，這裡是休士頓。請繼續，我們將在 TM 上監視你。
#
# 00 01 43 07 CDR
# 好的。序列邏輯，兩個。序列邏輯 1 和 2 即將啟動並開啟。
#
# 大巴哈馬群島（REV 2）
#
# 00 01 43 36 CC
# 阿波羅11號，這裡是休士頓。你已批准 RYRO ARM。
#
# 00 01 43 40 CDR
# 收到。謝謝你。
#
# 00 01 43 57 CC
# 阿波羅11號，這裡是休士頓。如果你在 ACC EPT 中給我們 P00，我們有你的狀態向量更新。
#
# 00 01 44 04 CDR
# 收到。
#
# 00 01 44 17 CDR
# 你在 ACCEPT 中有 P00。
#
# （GOSS NET 1）磁帶 2/4 第 12 頁
#
# 00 01 44 19 CC
# 收到。可能還需要 10 或 15 秒。我們要透過先鋒。當你準備好複製時，我有你的 TLI PAD。
#
# 00 01 44 26 CMP
# 收到。準備複製 TLI PAD。
#
# 00 01 44 30 CC
# 收到。TLI：23514 179 071 001，燃燒時間 547 104356 35575。SEP 的滾轉 357 107 041 301 287 319。TLI 10 分鐘中止俯仰，223。回讀。結束。
#
# 先鋒（REV2）
#
# 00 01 45 23 CMP
# 收到。TLI PAD：23514 179 071 001 547 104356 35575 357 107 041 301 287 319。TLI 1O 分鐘中止俯仰，223。結束。
#
# 00 01 46 03 CC
# 阿波羅11號，這裡是休士頓。收到。你是否再次回讀 DELTA-VC prime？你被一些噪音切斷了。
#
# 00 01 46 09 CMP
# 好的。收到。我也在這裡收到尖叫聲。DELTA-VC 104356。結束。
#
# 00 01 46 25 CC
# 阿波羅11號，這裡是休士頓。回讀正確。結束。
#
# 00 01 47 06 CC
# 阿波羅11號，這裡是休士頓。我們已完成上行鏈路；電腦是你的。你可以回到 BLOCK。你會驗證你是否已延伸探針嗎？結束。
#
# 00 01 47 16 CDR
# 收到。已驗證；探針已延伸。
#
# 00 01 47 19 CC
# 收到。距離本次州內傳輸的 LOS 約 2 分鐘。AOS 加那利群島在 1 50 13。結束。
#
# 00 01 47 28 CDR
# 收到。1 50。
#
# 加那利（REV 2）
#
# 00 01 50 42 CC
# 阿波羅11號，這裡是休士頓。結束。
#
# 00 01 50 45 CDR
# 收到。休士頓，阿波羅11號。大聲且清楚。
#
# （GOSS NET 1）磁帶 2/5 第 13 頁
#
# 00 01 50 49 CC
# 好的。關於你的服務模組 RCS 四 Bravo 封裝溫度，我們顯示它運行得有點低。看起來大約低了 20 度 - 比其他四個封裝低。你會確認四 Bravo 的 RCS 加熱器開關是否在 PRIMARY 中嗎？結束。
#
# 00 01 51 09 CDR
# 你是對的。它不在 PRIMARY 中。它現在開啟了。謝謝你。
#
# 00 01 51 16 CC
# 收到。謝謝你。
#
# 00 01 53 50 CC
# 阿波羅11號，這裡是休士頓。結束。
#
# 00 01 53 54 CMP
# 休士頓，阿波羅11號。請繼續。
#
# 00 01 53 56 CC
# 收到。我們檢查了太空船和發射載具的導航。它們看起來都處於良好狀態。我們估計你在發射載具上的導航關閉的機率高於 99%，因此事情顯然保持得非常好。供你參考，MILA 收到了大約 1 分鐘的可用的電視畫面，因此顯然系統正在運作。你距離加那利群島的 LOS 還有一分鐘多一點；AOS 塔那那利佛是 2 小時 9 分鐘 18 秒。結束。
#
# 00 01 54 34 CMP
# 收到。我們喜歡那些 99 的數字。謝謝你。
#
# 00 01 54 38 CC
# 收到。結束。
#
# 塔那那利佛（REV 2）
#
# 00 02 09 17 CC
# 阿波羅11號，這裡是透過塔那那利佛的休士頓。你讀到我嗎？
#
# 00 02 09 45 CC
# 阿波羅11號，這裡是休士頓，透過塔那那利佛待命。
#
# 00 02 10 03 CT
# 塔那那利佛，休士頓 COMM TECH NET 1。
#
# 00 02 10 12 CT
# 塔那那利佛，休士頓 COMM TECH NET 1。
#
# 00 02 10 23 CT
# Goddard 語音，休士頓 COMM TECH NET 1。
#
# 00 02 10 27 MSFN
# Goddard 語音，讀你大聲且清楚。
#
# （GOSS NET 1）磁帶 2/6 第 14 頁
#
# 00 02 10 29 CT
# 收到。我們無法聯絡到塔那那利佛。
#
# 00 02 10 31 CT
# 休士頓 COMM TECH，塔那那利佛。
#
# 00 02 10 34 CT
# 收到，塔那那利佛。你是否收到 CAP COMM 的語音，以及你是否正在上行鏈路傳送它？
#
# 00 02 10 39 CT
# 否定。
#
# 00 02 10 41 CT
# 收到。再次監視，我會告訴 CAP C0MM 再進行一次傳輸。
#
# 00 02 10 51 CT
# 收到。
#
# 00 02 10 56 CC
# 阿波羅11號，阿波羅11號，這裡是透過塔那那利佛待命的休士頓。結束。
#
# 00 02 11 04 CDR
# 休士頓，阿波羅11號 ...
#
# 00 02 11 06 CC
# 收到。讀你大聲且清楚。
#
# 00 02 12 35 CDR
# 休士頓，阿波羅11號。我們已啟動 PYRO。
#
# 00 02 12 39 CC
# 這裡是休士頓。收到。結束。
#
# 00 02 15 23 CC
# 阿波羅11號，這裡是休士頓。距離 LOS 塔那那利佛還有一分鐘；AOS 在卡納封 02 25 30。
#
# 00 02 15 35 CDR
# 收到。
#
# 卡納封（REV 2）
#
# 00 02 25 44 CC
# 阿波羅11號，這裡是透過卡納封的休士頓。無線電檢查。結束。
#
# 00 02 25 49 CDR
# 收到，透過卡納封的休士頓。阿波羅11號。大聲且清楚。
#
# 00 02 25 53 CC
# 收到。你在這裡傳輸得非常大聲且非常清楚。結束。
#
# 00 02 26 38 CC
# 阿波羅11號，這裡是休士頓。你已批准 TLI。結束。
#
# 00 02 26 45 CMP
# 阿波羅11號。謝謝你。
#
# 00 02 26 48 CC
# 收到。結束。
#
# 00 02 30 11 CC
# 阿波羅11號，這裡是休士頓。結束。
#
# 00 02 30 16 CDR
# 休士頓，11 號。
#
# （GOSS NET 1）磁帶 2/7 第 15 頁
#
# 00 02 30 18 CC
# 收到。我們將在大約 1 分鐘內進入 ARIA 飛機覆蓋範圍。他們這次將嘗試在 S 波段和 VHF 上進行上行鏈路傳輸。所以如果你們 - 確保

# %% [markdown]
# ## V. 類型配置

# %%
response = client.models.generate_content(
    model='gemini-2.0-flash-001',
    contents=types.Part.from_text(text='請問為何天空是藍色的？'),
    config=types.GenerateContentConfig(
        temperature=0,
        top_p=0.95,
        top_k=20,
        candidate_count=1,
        seed=5,
        max_output_tokens=100,
        stop_sequences=['STOP!'],
        presence_penalty=0.0,
        frequency_penalty=0.0,
    ),
)

print(response.text)
# Out:
# 天空之所以是藍色的，主要是因為一種叫做**瑞利散射 (Rayleigh scattering)** 的物理現象。以下是詳細的解釋：
#
# * **太陽光是混合光：** 太陽光並非單一顏色，而是由紅、橙、黃、綠、藍、靛、紫等各種顏色的光混合而成。
#
# * **大氣層中的微粒：** 地球的大氣層中充滿了各種微小的粒子，例如氮氣、氧

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/gemma-3-27b-it
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/aqa
# models/imagen-3.0-generate-002

# %% [markdown]
# ## V. Function Calling
#
# 此處示範，統整所有行政院最新新聞消息的 function calling。
#
# API 位置：https://opendata.ey.gov.tw/api/index.html

# %%
from typing import List, Union
from datetime import datetime, date
import requests

def normalize_date(date_str: Union[str, date]) -> str:
    """將輸入轉為 'YYYY/MM/DD' 字串格式"""
    if isinstance(date_str, date):
        return date_str.strftime('%Y/%m/%d')
    try:
        parsed = datetime.strptime(date_str, '%Y-%m-%d')
        return parsed.strftime('%Y/%m/%d')
    except ValueError:
        return date_str  # 假設已是 YYYY/MM/DD

def get_ey_news(start_date: str, end_date: str) -> List[dict]:
    """取得行政院公開新聞資料，日期會強制轉為 'YYYY/MM/DD'"""
    start_date_fmt = normalize_date(start_date)
    end_date_fmt = normalize_date(end_date)

    url = "https://opendata.ey.gov.tw/api/ExecutiveYuan/NewsEy"
    params = {
        "StartDate": start_date_fmt,
        "EndDate": end_date_fmt,
        "MaxSize": 10,
        "IsRemoveHtmlTag": True
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.json()

# %%
output = get_ey_news("2025/03/01", "2025/03/31")
output[0]
# Out:
# {'標題': '卓揆：確實盤點我國關鍵核心技術項目 確保國家安全和產業競爭力',
#  '內容': '<p>行政院長卓榮泰今（27）日於行政院會表示，教育部將召開「管制陸生修讀我國國家關鍵核心技術項目跨部會研商會議」，關鍵核心技術包括國防相關科技，以及各部會攸關臺灣產業競爭力的關鍵技術，請各部會務必確實盤點我國核心關鍵技術項目，於跨部會研商會議中完整通報，特別是國家科學及技術委員會、國防部、經濟部、農業部、數位發展部及海洋委員會等掌握關鍵核心技術的部會，務必確實提報，以利後續管控，有效確保國家安全。</p><p><br>有關內政部日前就維護社會治安所做的必要處置，卓院長請內政部劉世芳部長向警政署張榮興署長及全體同仁表達肯定。卓院長指出，國內幫派公然的不當行為引發社會關注，對國人、尤其是青少年，都造成負面觀感及不當影響，相關單位能有效遏止是最佳方法，請內政部、警政署及相關單位持續關注後續發展，若尚有其他不法行為，一律嚴查嚴辦。</p>',
#  '上版日期': '2025/03/27',
#  '來源網址': 'https://www.ey.gov.tw/Page/9277F759E41CCD91/1e85da89-638c-4ec6-b85a-eec8c02b4904'}

# %%
response = client.models.generate_content(
    model='gemini-2.0-flash-001',
    contents="幫我找 2025/03/01 至 2025/03/31 行政院發布的新聞標題和發佈時間",
    config=types.GenerateContentConfig(tools=[get_ey_news]),
)

print(response.text)
# Out:
# 2025/03/27
# * 卓揆：確實盤點我國關鍵核心技術項目 確保國家安全和產業競爭力
# * 清明連假將至 卓揆指示各部會相互聯防 充分發揮疏運措施功效 以確保民眾交通安全為最高原則
# * 政院通過「個人資料保護委員會組織法」草案及「個人資料保護法」部分條文修正草案 完備獨立監督機制及執法權限 建立AI全面應用時代資料治理
# * 卓揆：推動「114-118年健康臺灣深耕計畫」 打造更具韌性及包容性的健康照護模式 促進全民健康福祉
# 2025/03/26
# * 鄭副院長召開「穩定物價小組」會議，密切掌握清明應節農產品及民生物資價量情勢，並延長關鍵原物料稅負減徵措施至114年9月底，力求穩定民生物價
# * 卓揆赴臺南視察0121地震災後復原重建情形 指示一週內解決地方政府反映問題，讓民眾安心
# * 當心假冒身份證件詐騙再現 打詐指揮中心：請民眾提高警覺 避免受害損失
# 2025/03/20
# * 落實總統17項因應國安威脅策略 卓揆：律定各項行動計畫、策略及法制化期程
# * 政院通過「證券投資人及期貨交易人保護法」部分條文修正草案 健全公平安全交易環境、保障投資人權益
# * 卓揆：推動下一階段開放政府國家行動方案 落實透明、參與、課責核心價值

# %% [markdown]
# ## VII. Pydantic-JSON 回應架構

# %%
from pydantic import BaseModel


class CountryInfo(BaseModel):
    name: str
    population: int
    capital: str
    continent: str
    gdp: int
    official_language: str
    total_area_sq_mi: int


response = client.models.generate_content(
    model='gemini-2.0-flash-001',
    contents='請給我台灣的相關資訊',
    config=types.GenerateContentConfig(
        response_mime_type='application/json',
        response_schema=CountryInfo,
    ),
)
print(response.text)
# Out:
# {
#   "name": "Taiwan",
#   "population": 23500000,
#   "capital": "Taipei",
#   "continent": "Asia",
#   "gdp": 759100000000,
#   "official_language": "Mandarin Chinese",
#   "total_area_sq_mi": 13974
# }

# %% [markdown]
# ## VIII. Streaming Output

# %%
for chunk in client.models.generate_content_stream(
    model='gemini-2.0-flash-001', contents='請用100字講一個大野狼的故事'
):
    print(chunk.text, end='')
# Out:
# 月黑風高，大野狼舔著口水，盯上了迷路的小紅帽。他裝成慈祥奶奶，哄騙小紅帽進屋。
#
# 「奶奶，你的眼睛怎麼那麼大？」小紅帽天真地問。
#
# 「為了更清楚地看你！」
#
# 「奶奶，你的耳朵怎麼那麼大？」
#
# 「為了更清楚地聽你！」
#
# 「奶奶，你的嘴巴怎麼那麼大？」
#
# 「為了…吃了你！」大野狼撲了上去。獵人及時趕到，救下了小紅帽，狠狠教訓了貪婪的大野狼。

# %% [markdown]
# ## 生成圖片

# %%
import base64
import os
import mimetypes


def save_binary_file(file_name, data):
    f = open(file_name, "wb")
    f.write(data)
    f.close()

model = "gemini-2.0-flash-exp-image-generation"
contents = [
    types.Content(
        role="user",
        parts=[
            types.Part.from_text(text="""繪製一隻皮卡丘，站在噴火龍身上。"""),
        ],
    ),
]

generate_content_config = types.GenerateContentConfig(
    response_modalities=[
        "image",
        "text",
    ],
    response_mime_type="text/plain",
)

for chunk in client.models.generate_content_stream(
    model=model,
    contents=contents,
    config=generate_content_config,
):
    if not chunk.candidates or not chunk.candidates[0].content or not chunk.candidates[0].content.parts:
        continue
    if chunk.candidates[0].content.parts[0].inline_data:
        file_name = "output"
        inline_data = chunk.candidates[0].content.parts[0].inline_data
        file_extension = mimetypes.guess_extension(inline_data.mime_type)
        save_binary_file(
            f"{file_name}{file_extension}", inline_data.data
        )
        print(
            "File of mime type"
            f" {inline_data.mime_type} saved"
            f"to: {file_name}"
        )
    else:
        print(chunk.text)
# Out:
# 好的
# ，這是一個皮卡丘站在噴火龍身上的樣子：
#
#
# File of mime type image/png savedto: output
#
#
#
# 希望你喜歡！讓我知道你是否想看到其他不同的場景或角色
# 。

# %% [markdown]
# [ 只給 Vertex AI 用戶使用 ] 計算 token 數量

# %%
if gemini_type == "google-vertex-ai":
    response = client.models.compute_tokens(
        model='gemini-2.0-flash-001',
        contents='請問天空為何是藍色的？',
    )
    print(response)
